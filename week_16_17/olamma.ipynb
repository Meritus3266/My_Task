# %%
import ollama

# %%
response = ollama.chat(
    model="gemma3:1b",
    messages=[
        {"role": "user",
         "content": "Tell me a joke about computers."}
    ]
)
print(response["message"]["content"])
# Out:
# Why did the computer break up with the internet?
#
# Because it needed some space!
#
# ---
#
# Would you like to hear another one? 😊

# %%
response = ollama.chat(
    model = "gemma3:1b",
    messages =[
        {"role": "user",
         "content": "Write a poem about the sea in the style of Shakespeare."}
    ]
)

print(response["message"]["content"])
# Out:
# Hark, Muse, and lend thine ear to me,
# And let me sing of the boundless sea,
# A realm of power, vast and darkly deep,
# Where secrets slumber and the currents sleep.
#
# The sun doth kiss the waves with golden grace,
# And paints them bright in a most wondrous space,
# A liquid mirror, shifting, blue and white,
# Reflecting heavens in a dazzling light.
#
# The wind doth howl, a restless, mournful plea,
# And whips the foam with savage energy,
# While waves, like titans, surge and fiercely roll,
# And crash upon the shore, a captivating soul.
#
# The salty breath of ocean, sharp and bold,
# A scent of brine, a story to be told,
# Of sunken ships and treasures long since lost,
# And siren’s song, a tragically embossed.
#
# The depths conceal a mystery profound,
# Where coral gardens bloom without a sound,
# And monstrous creatures swim in shadowed lanes,
# Ignoring mortal man’s impatient strains.
#
# Yet, beauty dwells in this tumultuous sway,
# A restless spirit, holding night and day,
# A constant motion, ever flowing free,
# The Sea, a queen, for all eternity.
#
# So let me gaze upon this watery scene,
# And feel the power of this ancient sheen,
# For in its depths, a truth doth softly lie,
# Of boundless life, beneath a watchful sky.
