# %%
from google import genai
from dotenv import load_dotenv
import os

# %%
load_dotenv()
text = "Machine learning is a field of artificial intelligence that enables computers to learn from data and make predictions."
prompt = f"""Explain the key concepts of the text delimited by triple backticks in simple terms
```{text}```
"""
api_key = os.getenv("gemini_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# Let's break down the concepts in simple terms:
#
# 1.  **Machine Learning (ML):** Think of this as a special way of teaching computers. Instead of telling them every single step to solve a problem, you show them lots of examples, and they figure out the rules themselves.
#
# 2.  **Artificial Intelligence (AI):** This is the bigger picture. AI is about making machines smart, so they can think and act in ways that normally require human intelligence. Machine Learning is one *tool* or *method* within AI to achieve this.
#
# 3.  **Learn from Data:** This is how ML works. Imagine teaching a child to recognize a cat. You don't give them a list of rules ("it has whiskers, four legs, pointy ears..."). Instead, you show them many pictures of cats and point out, "That's a cat," until they learn to identify new cats on their own. "Data" is all those pictures and examples you show the computer.
#
# ...

# %%
# One short prompting
text = "Machine learning is a field of artificial intelligence that enables computers to learn from data and make predictions."
prompt = f"""Translate the text delimited by triple backticks in simple terms,Translate all this sentences in english to french
```{text}```
"""
api_key = os.getenv("api_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# Voici la traduction en français simple :
#
# **L'apprentissage automatique est un domaine de l'intelligence artificielle qui permet aux ordinateurs d'apprendre à partir de données et de faire des prédictions.**

# %%
# Few shot prompting
prompt = """ Determine the sentiment of the following sentences:
Sentence: "I love this prouduct! it works great and exceeded my expectations."
Sentiment: Positive
Sentence: "This is the worst service I have ever received."
Sentiment: Negative
Sentence: "The movie was okay, not too bad but not great either."
Sentiment: Neutral
Sentence: "I am extremely satisfied with my purchase."
Now analyze the following sentence:
"""
api_key = os.getenv("api_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# Sentiment: Positive

# %%
# Multi-step prompting
text = "Marie Curie discovered radiumm 1898"
prompt =f"""You will be provided with a text delimited by triple backticks.
Step 1: Identify the key entities in the sentence.
Step 2: Classify each entity as a person, event, or object.
'''{text}'''"""
api_key = os.getenv("api_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# **Step 1: Identify the key entities in the sentence.**
# *   Marie Curie
# *   radium
# *   discovery of radium (implied event, occurring in 1898)
#
# **Step 2: Classify each entity as a person, event, or object.**
# *   **Marie Curie:** Person
# *   **radium:** Object
# *   **discovery of radium:** Event

# %%
# Chain of thought prompting
prompt = "John has 3 apples. He buys 5 more and gaves away 2. How many apples does he have now? think step by step."
api_key = os.getenv("api_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# Let's break it down step by step:
#
# 1.  **Starting apples:** John has 3 apples.
# 2.  **Buys more:** He buys 5 more apples.
#     *   So, 3 + 5 = 8 apples.
# 3.  **Gives away:** He gives away 2 apples.
#     *   So, 8 - 2 = 6 apples.
#
# John has **6** apples now.

# %%
# Self-Constructing Prompts (SCP)
instruction = "Imagine there completely independent experts who reason differently are answering this question. The final answer is obtained by majority vote. The question is: "
question = "A bookstore has 20 books ona shelf. A costumer buys 5 books. How many books. Then store restocks with double the number of bought. After that, another customer buys 8. How books are left on the shelf?"
prompt = instruction + question
api_key = os.getenv("api_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# Let's break this down step-by-step, as three independent experts would, to ensure clarity and agreement for a majority vote.
#
# **Expert 1's Reasoning:**
#
# 1.  **Initial state:** The shelf starts with **20 books**.
# 2.  **First customer's purchase:** A customer buys 5 books.
#     *   Books remaining: 20 - 5 = **15 books**.
# 3.  **Restocking:** The store restocks with double the number of books bought (by the first customer).
#     *   Number bought = 5 books.
#     *   Double that = 5 * 2 = 10 books.
#     *   Books on shelf after restocking: 15 + 10 = **25 books**.
# 4.  **Second customer's purchase:** Another customer buys 8 books.
#     *   Books remaining: 25 - 8 = **17 books**.
#
# **Expert 2's Reasoning:**
#
# "Following the sequence of events exactly as described:"
#
# *   Start: 20
# *   Customer 1 buys 5: 20 - 5 = 15
# *   Restock double what was just bought (5 * 2 = 10): 15 + 10 = 25
# *   Customer 2 buys 8: 25 - 8 = 17
#
# **Expert 3's Reasoning:**
#
# ...

# %%
# Role playing prompts
prompt = "Act as an experienced hiring manager. Ask me five interview questions one by one. After i respond, provide constructive feedback on my answer, including strengths and areas for improvement. if my response is incomplete, guide me towards a better answer." 

user_prompt = "I'm preparing for a Data Scientist interview. can you ask me five questions and evaluate my responses?"

api_key = os.getenv("api_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# Alright, welcome! Thanks for coming in today. My name is [Your Name/Generic HM Name], and I'll be leading our conversation. We're very excited about this role, and I'm looking forward to learning more about your experience and how you might fit into our team.
#
# Before we dive into your specific background, let's start with something foundational.
#
# **Question 1:** Tell me a little bit about yourself and what brought you here today.

# %%
system_prompt = "Act as an experienced hiring manager. Ask me five interview questions one by one. After I respond, provide constructive feedback on my answer, including strengths and areas for improvement. If my response is incomplete, guide me toward a better answer."
user_prompt = "I'm preparing for a Data Scientist interview. Can you ask me fine five questions and evaluate my responses?"
chat = client.chats.create(
    model="gemini-2.5-flash",
    config= genai.types.GenerateContentConfig(
        system_instruction = system_prompt,
        temperature=0.
    )
)
response = chat.send_message(user_prompt)
print(response.text)
while True:
    print(f"User is Speaking \n")
    user_input = input("\nYou: ")
    response = chat.send_message(user_input)
    print(f"Gemini is Speaking: \n{response.text}")

# %%
name = "Timi"
age = 14

prompt = f"Write a biirthday message for {name} who is turning {age} years old."

api_key = os.getenv("api_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# Here are a few options, choose the one that best fits your relationship with Timi!
#
# **Option 1: Warm & Encouraging**
#
# Happy 14th Birthday, Timi!
#
# Wow, 14 already! This is such an exciting age, full of new adventures, discoveries, and becoming even more of the amazing person you are. May your special day be filled with everything you love – laughter, fun, delicious cake, awesome presents, and being surrounded by family and friends.
#
# As you step into your mid-teens, I wish you a year ahead filled with happiness, new passions, great memories, and the courage to chase all your dreams. Keep shining bright, Timi!
#
# Have the most fantastic birthday ever!
#
# With lots of love and best wishes,
# [Your Name]
#
# ---
#
# **Option 2: Fun & Enthusiastic**
#
# Happy BIG 1-4, Timi!
#
# ...

# %%
name = "John"
age = 30
interest = "coding"

# %%
user_profile = {
    "name": "Zara",
    "interest": "coding",
    "goal": "Learn AI",
    "tone": "friendly",
    "Length": "short"  
}
prompt = f"""My name is {user_profile['name']}. I love {user_profile['interest']} birthday message for {user_profile['name']} who is turning {age} years old and loves {user_profile['interest']} and want to {user_profile['goal']}. Write a {user_profile['tone']} and {user_profile['Length']}. Guide how i can start."""

print("generated prompt:\n", prompt)
# Out:
# generated prompt:
#  My name is Zara. I love coding birthday message for Zara who is turning 30 years old and loves coding and want to Learn AI. Write a friendly and short. Guide how i can start.

# %%
Text = "I ordered this smartphone lastweek, and I'm really immpressed! The battery lasts all day,  the camera quality is amazing,"

# %%
text = """@LS_King: YO why'd you blow up my car?!
@ThugLife99: cry about it  
#GetReckt
 """
prompt = f"""Analyze this GTA Online tweet fight:
1. Who started it?
2. Most Toxic word?
3. Suggested peace treaty (funny):
'''{text}'''
 """
api_key = os.getenv("api_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# Here's an analysis of your GTA Online tweet fight:
#
# 1.  **Who started it?**
#     In terms of the *tweet fight itself*, **@LS_King** started it by posting the initial complaint about their car being blown up. However, in terms of the *in-game action that led to the tweet fight*, **@ThugLife99** started the conflict by blowing up @LS_King's car.
#
# 2.  **Most Toxic word?**
#     The most toxic word is **"cry"** (as part of "cry about it"). It's a dismissive and belittling word meant to invalidate @LS_King's frustration and mock their emotional response, suggesting weakness. "#GetReckt" is also toxic as it's gloating and taunting, but "cry" directly attacks the person's feelings.
#
# 3.  **Suggested peace treaty (funny):**
# ...

# %%
text = "Telsa is an electric vehicle company. Its stock price has increasedby 20% in the last year. Apple is a technology company known for its iphones. Its stock price has increased by 15% in the last year. Amazon is an e-commerce and cloud computing giant. Its stock price has increased by 10% in the last year.the last year."

prompt = f"""Convert the following text into a table showing the company names and their respective stock price increases over the last year.
'''{text}'''
 """

api_key = os.getenv("api_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# | Company Name | Stock Price Increase (Last Year) |
# |--------------|----------------------------------|
# | Telsa        | 20%                              |
# | Apple        | 15%                              |
# | Amazon       | 10%                              |

# %%
text = "Artificial Intelligence is transforming industries like healthcare, finance, and education by improving efficiency and decision making."
prompt = f"""Format the response in a list:
- Summarize the key industries AI is transforming.
- Highlight its impact.
Text: ```{text}```"""


api_key = os.getenv("api_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# Here's the summary in a list format:
#
# *   **Key Industries AI is Transforming:** Healthcare, finance, and education.
# *   **Impact:** Improving efficiency and decision-making within these industries.

# %%
text = "John is a data scientist with expertise in python and machine learning."
prompt = f"""Extract key details from the text and return the output in JSON format.
Text: ```{text}```
Output format:
{{
  "name": "",
  "profession": "",
  "skills": []
}}
"""
api_key = os.getenv("api_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# ```json
# {
#   "name": "John",
#   "profession": "data scientist",
#   "skills": ["python", "machine learning"]
# }
# ```

# %%
prompt = "Write a structured paragraph with clear headings and subheadings about the impact of a balanced diet and physical and mental health."

api_key = os.getenv("api_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# A balanced diet is foundational to holistic well-being, profoundly influencing both physical and mental health through various synergistic mechanisms.
#
# **Physical Health Benefits:**
# *Sustained Energy and Vitality:* By providing essential macronutrients and micronutrients, a balanced diet fuels the body consistently, preventing energy crashes and supporting overall vitality.
# *Disease Prevention and Immune Resilience:* It significantly reduces the risk of chronic conditions like heart disease, type 2 diabetes, and certain cancers, while bolstering the immune system's ability to fight off infections.
# *Optimal Bodily Function:* Furthermore, proper nutrition ensures the efficient functioning of all organs, promotes muscle development, maintains bone density, and supports cellular repair.
#
# **Mental Well-being Enhancement:**
# *Cognitive Function and Clarity:* Crucially, a well-nourished brain functions optimally, enhancing concentration, memory, and problem-solving abilities.
# ...

# %%
text = """
In a distant Kingdom, a brave knight named Arthur set out on a quest to find the legendary sword of light.
Through treacherous mountains and dark forests, he faced numerous challenges but remained determined to fulfill his destiny.
"""
prompt = f"""
You will be provided with a text delimited by triple backticks.
If the text is short (around 20 words or fewer), generate a suitable **Title**.
If the text is longer than 20 words, generate a concise **Summary**.
Use the following format for the output:
  Text: <provided text>
  Title/Summary: <generated content>
Text:
```{text}```
"""


api_key = os.getenv("api_key")
client = genai.Client(api_key = api_key)
response = client.models.generate_content(
    model = "gemini-2.5-flash", contents = prompt
)
print(response.text)
# Out:
# Text: In a distant Kingdom, a brave knight named Arthur set out on a quest to find the legendary sword of light. Through treacherous mountains and dark forests, he faced numerous challenges but remained determined to fulfill his destiny.
# Summary: Knight Arthur embarks on a quest for the legendary sword of light, overcoming challenges with unwavering determination.
